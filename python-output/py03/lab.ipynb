# %% [markdown]
# # [3주차 실습] 파이썬 마법 주문: 변수와 문자열 조작
#
# 안녕하세요! 서울신학대학교 1학년 여러분. 이번 주차 실습에 오신 것을 환영합니다. 아래 셀에 있는 코드를 확인하고 직접 코딩을 실행해 보세요.
# 실습에서 여러분의 상상력을 맘껏 펼치고 코드를 캡처해서 eCampus에 자랑스럽게 제출합시다!

# %% [markdown]
# ## 미션 1: 이름표 만들기 (변수 할당)
# 여러분의 이름과 지금 가장 좋아하는 요리를 변수에 넣어보세요! 큰따옴표("")의 짝을 맞추는 것 잊지 마세요.

# %%
# 아래 빈칸의 따옴표 안에 정보를 채워보세요!
my_name = ""
favorite_food = ""

print("Hello! 내 이름은", my_name, "입니다. 제일 좋아하는 음식은", favorite_food, "랍니다.")

# %% [markdown]
# ## 미션 2: 글자 요리조리 자르기 (인덱싱 & 슬라이싱)
# 아래 문자열에서 **'Python'** 이라는 단어만 정확히 분리해 보세요! 파이썬의 번호는 0부터 시작한다는 것을 꼭 기억하세요.

# %%
magic_word = "I love Python programming!"

# 인덱싱과 슬라이싱을 이용해 'Python'만 잘라보세요.
# 힌트: 'P'의 위치부터 'n'의 위치 다음 번호까지!
sliced_word = ""
print("내가 찾아낸 단어:", sliced_word)

# %% [markdown]
# ## 미션 2-1: 건너뛰며 글자 뽑기 (Step 슬라이싱)
# 문자열에서 2칸씩 건너뛰며 글자를 뽑아 숨겨진 암호를 해독해 보세요! `[시작:끝:보폭]` 규칙을 사용합니다.

# %%
secret_code = "HXeXlXlXoX!X"

# 콜론 두 개를 써서 X를 건너뛰고 Hello!만 뽑아내 보세요.
decoded_word = ""
print("해독된 암호:", decoded_word)

# %% [markdown]
# ## 미션 3: 대문자로 소리치기 (문자열 메서드 활용)
# 주어진 문장을 모두 대문자로 바꿔서 전 세계로 씩씩하게 출력해 보세요!

# %%
quiet_message = "hello fellow students! let's enjoy coding in python."

# .upper() 메서드를 사용해서 새로운 변수에 저장해보세요!
loud_message = ""
print("큰 소리로:", loud_message)

# %% [markdown]
# ## 미션 4: f-string으로 마법의 명함 만들기 (최종 보스!)
# `input()`을 이용해 사용자의 이름과 고향 국가를 입력받고, f-string을 이용해 깔끔한 명함 텍스트를 완성하세요.

# %%
# input()으로 사용자 정보를 물어봅니다.
user_name = input("당신의 이름은 무엇인가요? ")
user_country = input("어느 나라에서 오셨나요? ")

# f-string 마법을 부릴 시간입니다!
# 예시 표출 형태: 환영합니다! [이름] 님은 [나라]에서 오셨군요! 정말 반갑습니다.
intro_message = f""
print(intro_message)
