# %% [markdown]
# # [S1] 변수란 무엇인가, 그리고 네이밍 규칙

# %%
age = 20
name = "Wonhyuk"
age = 21

score = 100
score = score + 10
score += 10

student_name = "Hong Gil Dong"

# %% [markdown]
# ### 변수 심화: 다중 할당
# 한 줄에 여러 변수를 만들어 보겠습니다.

# %%
midterm, final, quiz = 95, 65, 90
print(midterm, final, quiz)

# %% [markdown]
# # [S2] 문자열 심화 및 조작

# %%
text = "Hello"
print(text[0])
print(text[-1])
print(text[0:4])
print(text[0:5:2])

# %%
message = "  I am a Python KING!  "
print(message.upper())
print(message.replace("KING", "Student"))
print(message.strip())
print(message.split())
print(len(message))

# %% [markdown]
# ### 문자열 & 리스트 심화 메서드
# `.join()`, `.count()`, `.index()` 등 실무에서 유용한 기능들입니다.

# %%
words = ['Python', 'is', 'Fun']
joined_text = " ".join(words)
print(f"Joined: {joined_text}")

print(f"'h' count: {'hello python'.count('h')}")

print(f"'Python' index: {words.index('Python')}")

# %% [markdown]
# ### 리스트 기초 실습 (추가, 삭제, 복제)
# 변수 상자 안의 내용물을 넣고 빼는 기본 돔작입니다.

# %%
stu01 = ["Geoffery Hinton", 95, 65, 90]
stu01.append(100) # 맨 끝에 추가
print(f"After append: {stu01}")

del stu01[0] # 이름 삭제
print(f"After del: {stu01}")

stu_new = stu01.copy()
print(f"Copied list: {stu_new}")

# %% [markdown]
# # [S3] f-string 문법의 마법과 강사 라이브 코딩

# %%
name = input("안녕하세요! 당신의 이름은 무엇인가요? ")
age_str = input("만나서 반갑습니다. 나이가 어떻게 되시는지 알려주시겠어요? ")

# %%
intro_msg = f"놀랍습니다! {name} 님의 나이는 {age_str}세 이시군요. 정말 젊고 멋진 나이입니다. 환영합니다!"
print(intro_msg)

# %% [markdown]
# ### f-string 소숫점 및 정렬
# f-string을 통해 출력 혐태를 정교하게 조절합니다.

# %%
val = 3.512345
print(f"[소숫점 두자리] {val:.2f}")

s = "Hello"
print(f"[오른쪽 정렬] {s:>10s}")
print(f"[가운데 정렬] {s:^10s}")
