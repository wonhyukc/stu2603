# %% [markdown]
# # 컴사코 4주차 실습: 조건문 (if-elif-else)
# 이번 실습에서는 프로그램의 논리적 분기를 제어하는 조건문을 다룹니다. 완성된 코드를 보는 것이 아니라, **직접 빈칸(TODO)을 채우고 의도된 버그를 찾아 수정**해야 합니다.

# %% [markdown]
# ## [S1] if-elif-else 기초 실습
# **목표**: `score` 변수의 값에 따라 다른 메시지를 출력하도록 `elif`와 `else` 블록을 완성하세요.
# - 90점 이상: "합격입니다!"
# - 70점 이상 ~ 90점 미만: "대기 상태입니다."
# - 70점 미만: "불합격입니다."

# %%
score = 75

if score >= 90:
    print("합격입니다!")
# TODO 1: 70점 이상일 경우 "대기 상태입니다."를 출력하는 elif 문을 작성하세요.

# TODO 2: 그 외의 경우 "불합격입니다."를 출력하는 else 문을 작성하세요.

# %% [markdown]
# ## [S2] 논리 연산자 (and, or, not) 디버깅 실습
# **목표/상황**: 놀이공원의 롤러코스터는 키가 130cm 이상이고(`and`) 티켓을 가지고 있어야 탈 수 있습니다. 단, 심장질환이 있는 사람(has_disease == True)은 조건을 만족해도 탈 수 없습니다(`not`).
#
# **문제**: 아래 코드는 누군가 잘못 작성하여, 심장질환이 있는데도 탈 수 있다고 출력합니다. 논리 연산 구조를 분석하고 올바르게 **디버깅(수정)**하세요.

# %%
height = 140
has_ticket = True
has_disease = True  # 심장질환이 있음

# 의도된 버그: 아래 줄의 논리 연산자 조합이 잘못되었습니다. 수정해 보세요!
if height >= 130 or has_ticket and has_disease:
    print("놀이기구 탑승이 가능합니다!")
else:
    print("탑승 조건을 만족하지 못했습니다.")

# %% [markdown]
# ## [S3] 사용자 입력과 학점 계산기 실습
# **목표**: 사용자로부터 점수를 직접 `input()`으로 입력받아, 조건문을 사용해 A, B, C 학점을 판별하는 계산기를 만듭니다.
#
# **요구사항**:
# 1. `input()`으로 받은 값은 문자열이므로, 숫자로 변환하는 과정이 필요합니다.
# 2. 0~100 사이의 값이 아니면 오류 메시지를 먼저 출력하도록 방어 로직을 작성하세요.
# 3. 90 이상은 A, 80 이상은 B, 나머지는 C로 판별하세요.

# %%
score_input = input("점수를 입력하세요(0~100): ")

# TODO 3: score_input을 정수(int)로 변환하여 score 변수에 저장하세요.
score = 

# TODO 4: if-elif-else 구조를 사용하여 요구사항에 맞는 학점 판별기를 완성하세요.
if # 조건 1: 0 미만이거나 100 초과일 때:
    print("오류: 점수는 0에서 100 사이여야 합니다.")
elif # 조건 2: 90 이상:
    print("A학점 입니다.")
# 이하 B학점 판단 로직 및 C학점 판단 로직 완성
