# %% [markdown]
# # 컴사코 4주차 실습: 조건문 (if-elif-else)
# 이번 실습에서는 프로그램의 논리적 분기를 제어하는 조건문을 다룹니다. 완성된 코드를 보는 것이 아니라, **직접 빈칸(TODO)을 채우고 의도된 버그를 찾아 수정**해야 합니다.

# %% [markdown]
# ## [S1] if-elif-else 기초 실습
# **Step 1. 다중 분기 기본 완성하기**
# `score` 변수의 값에 따라 다른 메시지를 출력하도록 `elif`와 `else` 블록을 완성하세요.
# - 90점 이상: "합격입니다!"
# - 70점 이상 ~ 90점 미만: "대기 상태입니다."
# - 70점 미만: "불합격입니다."

# %%
score = 75

if score >= 90:
    print("합격입니다!")
# TODO 1: 70점 이상일 경우 "대기 상태입니다."를 출력하는 elif 문을 작성하세요.

# TODO 2: 그 외의 경우 "불합격입니다."를 출력하는 else 문을 작성하세요.

# %% [markdown]
# **Step 2. 논리적 순서 버그 수정 (의람된 버그)**
# 아래 코드는 학점을 부여하는 코드입니다. 하지만 95점을 입력해도 'B등급'이 나옵니다! 그 이유를 찾아서 주석으로 적고, 코드를 올바른 순서로 수정하세요.

# %%
test_score = 95

# TODO 3: 아래 로직의 논리적 허점을 주석으로 분석하고 올바르게 고치세요!
if test_score >= 80:
    print("B등급")
elif test_score >= 90:
    print("A등급")
else:
    print("C등급")

# %% [markdown]
# ## [S2] 논리 연산자 (and, or, not) 디버깅 및 응용 실습
# **Step 3. 복합 논리식 완성하기**
# 영화관에서 VIP 회원(`is_vip`)이거나 조조할인 시간(`is_morning`)이면 50% 할인을, 둘 다 아니면 할인 없음 메시지를 출력하세요.

# %%
is_vip = False
is_morning = True

# TODO 4: 올바른 논리 연산자(and/or)를 사용하여 if문을 완성하세요.
if # 여기에 조건식 작성:
    print("50% 할인 적용!")
else:
    print("할인 없음.")

# %% [markdown]
# **Step 4. 심장병 논리 디버깅 (의도된 버그)**
# 롤러코스터는 키가 130cm 이상이고(`and`) 티켓을 가지고 있어야 탈 수 있습니다. 단, 심장질환이 있는 사람(has_disease == True)은 조건을 만족해도 탈 수 없습니다(`not`).
# 아래 코드는 누군가 잘못 작성하여, 심장질환이 있는데도 탈 수 있다고 출력합니다. 원인을 주석으로 분석하고(우선순위 문제 등) 괄호를 사용하여 명확히 디버깅하세요.

# %%
height = 140
has_ticket = True
has_disease = True  # 심장질환이 있음

# TODO 5: 아래 구문의 맹점을 주석으로 서술하고 올바르게 수정하세요.
if height >= 130 or has_ticket and not has_disease:
    print("놀이기구 탑승이 가능합니다!")
else:
    print("탑승 조건을 만족하지 못했습니다.")

# %% [markdown]
# ## [S3] 사용자 입력과 학점 계산기 점진적 빌드업
# 이제 3개의 셀에 걸쳐 계산기를 점진적으로 완성해봅니다.
# **Step 5: 입력 받기 및 형변환**

# %%
raw_input = input("점수를 입력하세요(0~100): ")

# TODO 6: raw_input을 정수(int)로 변환하여 score 변수에 저장하세요.
score = 
print(f"변환된 점수: {score}, 타입: {type(score)}")

# %% [markdown]
# **Step 6. 오류 방어(Validation) 로직 추가**
# 점수가 0 미만이거나 100 초과일 경우 오류 메시지를 출력하고, 정상일 경우에만 "정상 점수입니다"를 출력하게 하세요.

# %%
# 위에서 받은 score 변수를 그대로 사용합니다.
# TODO 7: if-else문을 작성하여 비정상 점수를 차단하세요.
if # 조건:
    print("오류: 점수는 0에서 100 사이여야 합니다.")
else:
    print("정상 점수입니다.")

# %% [markdown]
# **Step 7. 통합 완성판 조립**
# 이제 입력(Step 5)부터 방어 로직(Step 6), 그리고 상세한 학점 로직(A, B, C 지정)을 모두 하나로 합쳐서 완성하세요!

# %%
# TODO 8: 전체 로직을 완성하세요!
# 1. 0~100 범위 밖이면 즉시 경고 출력
# 2. 해당 범위 내라면 다시 90 이상 A, 80 이상 B, 나머지 C 판별.
