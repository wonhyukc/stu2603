# %% [markdown]
# # 2.자료형(Container) - Dictionaries
#
# - (key, value) 구조.
# - index의 개념.
# - 순서의 의미가 없음

# %%
# dictionary 생성
d = {'cat': 'cute', 'dog': 'furry'}
print(d)

# dictionary 특정 값 조회
print(d['cat'])

# key 값이 들어있는지 확인
print('cat' in d)
print('sheep' in d)
# Out:
# {'cat': 'cute', 'dog': 'furry'}
# cute
# True
# False

# %%
# 새로운 (key, value) 추가
d['fish'] = 'wet'
print(d['fish'])
print(d)
# print(d['monkey'])  # KeyError: 'monkey'를 key로 가진 value가 없다
# Out:
# wet
# {'cat': 'cute', 'dog': 'furry', 'fish': 'wet'}

# %%
# key가 없는 경우, default value 사용
print(d.get('monkey')) # 오류 발생
print(d.get('monkey', 'N/A')) # 오류 발생하지 않는다.
print(d.get('fish', 'N/A'))
# Out:
# None
# N/A
# wet

# %%
# 요소 삭제
del d['cat']
print(d['fish'])
print(d)

# %%
l = ['cute', 'furry']
d = { 1:'정원혁', 2:'정수연'}
print(d)
print(d[2])
d[4] = '이주영'
print(d)
# Out:
# {1: '정원혁', 2: '정수연'}
# 정수연
# {1: '정원혁', 2: '정수연', 4: '이주영'}

# %% [markdown]
# #### 반복문 with 딕셔너리

# %%
# 반복문
d = {'person': 2, 'cat': 4, 'spider': 8}
for key in d:
    value = d[key]
    print('A %s has %d legs' % (key, value))

d = {'person': 2, 'cat': 4, 'spider': 8}
for key, value in d.items():
    print('A %s has %d legs' % (key, value))

# %% [markdown]
# #### dictionaries comprehension

# %%
# 확장 문법 - 반복문 + 제어문
animals = {'cat': 11, 'dog': 7, 'fish': 15, 'horse': 3}
animals_over_10 = {k: v for k, v in animals.items() if v > 10}
print(animals_over_10)  # "{'cat': 11, 'fish': 15}"

# 튜플로 만든 후, dict로 변환
# 튜플: 이 장의 뒤에서 배웁니다
animals_over_11 = dict([(k, v) for k, v in animals.items() if v > 10])
print(animals_over_11)  # "{'cat': 11, 'fish': 15}"
# Out:
# {'cat': 11, 'fish': 15}
# {'cat': 11, 'fish': 15}

# %% [markdown]
# ### 실습: Dictionaries

# %%
stu01 = {
    "no": 1,
    "name": "Geoffery Hinton",
    "points": [92, 96, 98]
}
stu02 = {
    "no": 2,
    "name": "Yann Lecun",
    "points": [58, 64, 100]
}
stu03 = {
    "no": 3,
    "name": "Yoshua Bengio",
    "points": [88, 84, 92]
}
stu04 = {
    "no": 4,
    "name": "Andrew Ng",
    "points": [75, 85, 100]
}

stu = [stu01, stu02, stu03, stu04]

# %%
#1. 각 학생들의 번호에 10씩 더하세요.
# Out:
# [{'no': 11, 'name': 'Geoffery Hinton', 'points': [92, 96, 98]}, {'no': 12, 'name': 'Yann Lecun', 'points': [58, 64, 100]}, {'no': 13, 'name': 'Yoshua Bengio', 'points': [88, 84, 92]}, {'no': 14, 'name': 'Andrew Ng', 'points': [75, 85, 100]}]

# %%
#2. 각 학생별로 점수 합계를 구하세요.
for i in stu:
# Out:
# 286
# 222
# 264
# 260

# %%
#3 'tot' 항목을 추가하여 위에서 구한 결과를 넣으세요.
#2. 각 학생별로 점수 합계를 구하세요.
for i in stu:
    # print(sum(i['points'][:]))
    tot =

    print(i)
# Out:
# {'no': 1, 'name': 'Geoffery Hinton', 'points': [92, 96, 98], 'tot': 286}
# {'no': 2, 'name': 'Yann Lecun', 'points': [58, 64, 100], 'tot': 222}
# {'no': 3, 'name': 'Yoshua Bengio', 'points': [88, 84, 92], 'tot': 264}
# {'no': 4, 'name': 'Andrew Ng', 'points': [75, 85, 100], 'tot': 260}

# %%
#4 아래 out 문자열을 이용하여 학생들의 번호, 이름, 평균점수를 출력하세요.
out = "번호: %d, 이름: %s, 평균점수: %.1f"
for i in stu:
# Out:
# 번호: 1, 이름: Geoffery Hinton, 평균점수: 95.3
# 번호: 2, 이름: Yann Lecun, 평균점수: 74.0
# 번호: 3, 이름: Yoshua Bengio, 평균점수: 88.0
# 번호: 4, 이름: Andrew Ng, 평균점수: 86.7

# %%
#5 모든 학생의 key: value를 출력하는 코드를 작성하세요.
# Out:
# {'no': 1, 'name': 'Geoffery Hinton', 'points': [92, 96, 98], 'tot': 286, 'avg': 95.33}
# {'no': 2, 'name': 'Yann Lecun', 'points': [58, 64, 100], 'tot': 222, 'avg': 74.0}
# {'no': 3, 'name': 'Yoshua Bengio', 'points': [88, 84, 92], 'tot': 264, 'avg': 88.0}
# {'no': 4, 'name': 'Andrew Ng', 'points': [75, 85, 100], 'tot': 260, 'avg': 86.67}
