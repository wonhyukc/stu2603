# %% [markdown]
# # 1주차 실습: 오리엔테이션과 개관
#
# 이 노트북은 **Google Colab** 환경에서 파이썬 코드를 실행해 보기 위한 첫 실습입니다.

# %% [markdown]
# ## Lab 1. 화면에 글자 출력하기
#
# 아래 회색 코드 셀 안을 클릭한 뒤, `안녕하세요!` 라는 글자가 출력되도록 코드를 작성해 보세요.
# 다 썼으면 셀 왼쪽의 재생 버튼(▶)을 누르거나 키보드에서 `Shift` + `Enter`를 동시에 누릅니다.

# %%
print("안녕하세요!")

# %% [markdown]
# ## Lab 2 & Lab 3 진행
#
# 이번 주차의 나머지 실습인 **GitHub 계정 생성** 및 **AI 계정 생성/질문**은 콜랩 바깥의 브라우저 탭에서 진행됩니다. `handout.md` 또는 강사님의 안내 구두 지시를 따라 진행해 주세요.
