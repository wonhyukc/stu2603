# %% [markdown]
# # 2주차 실습: 개발 환경 및 출력
#
# 이 노트북은 `py02` 주차의 실습을 위한 파일입니다. 강사님의 안내에 따라 아래 실습을 차례대로 진행해 주세요.

# %% [markdown]
# ## 1. 다양한 데이터 출력 워밍업
#
# 아래 빈 코드 셀에서 `print(100)`, `print(3.14)`, 그리고 `print("나의 나이는", 20, "살입니다.")` 를 입력하고 실행해 보세요.

# %%
# 여기에 코드를 입력하고 실행하세요 (Shift + Enter)

# %% [markdown]
# ## Lab 1. 문자열과 숫자 연산의 응용
#
# 덧셈 연산과 이어붙이기 연산을 비교해 봅니다. `print(50 + 50)`과 `print("50" + "50")`을 각각 실행해 보고, 추가로 `print("=" * 30)`을 실행해 화면을 꾸며보세요.

# %%
# 여기에 코드를 입력하고 실행하세요

# %% [markdown]
# ## Lab 2. 고의로 문법 에러 만들고 디버깅하기 (SyntaxError)
#
# **Step 1:** 아래 셀의 코드는 일부러 괄호가 빠져 있습니다. 실행해서 에러 메시지(빨간 박스)를 관찰하세요.
# **Step 2:** 에러 메시지를 복사하여 AI 파트너에게 물어보고 원인을 파악한 뒤 코드를 고쳐보세요.

# %%
print"안녕하세요파이썬"

# %% [markdown]
# ## Lab 3. 오타 내고 AI와 토론하기 (NameError)
#
# **Step 1:** 이번에는 함수 이름에 오타를 내보겠습니다. `pint("안녕")`을 실행해 보세요.
# **Step 2:** 발생하는 `NameError`를 AI에게 물어보고, 이전의 `SyntaxError`와 어떻게 다른지 토론해 보세요.

# %%
pint("안녕")
